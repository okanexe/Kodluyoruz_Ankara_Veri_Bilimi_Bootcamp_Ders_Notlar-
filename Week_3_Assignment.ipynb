# %%
import pandas as pd 
import numpy as np
data = pd.read_excel("dataset.xlsx")
data
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0        19     17  100.000000  85.714286  14.285714  72.363515  60.808814
# 1        24     19  100.000000  78.571429  21.428571  74.275883  64.366798
# 2        30     24  100.000000  71.428571  28.571429  75.140402  65.915803
# 3        37     30  100.000000  64.285714  35.714286  76.677846  68.584234
# 4        41     37  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162     27     31   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163     22     27   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164     19     22   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165     19     19  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166     19     19   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
data.replace('?',np.nan)
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0        19     17  100.000000  85.714286  14.285714  72.363515  60.808814
# 1        24     19  100.000000  78.571429  21.428571  74.275883  64.366798
# 2        30     24  100.000000  71.428571  28.571429  75.140402  65.915803
# 3        37     30  100.000000  64.285714  35.714286  76.677846  68.584234
# 4        41     37  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162     27     31   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163     22     27   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164     19     22   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165     19     19  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166     19     19   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6167 entries, 0 to 6166
# Columns: 136 entries, ind_5 to 90_target
# dtypes: float64(88), int64(45), object(3)
# memory usage: 6.3+ MB

# %%
data.describe()["ind_324"]
# Out:
# count    6167.000000
# mean       -0.000074
# std         0.000133
# min        -0.001550
# 25%        -0.000098
# 50%         0.000000
# 75%         0.000000
# max         0.000000
# Name: ind_324, dtype: float64

# %%
data.groupby("ind_109").sum()
# Out:
#          ind_5  ind_6          ind_8          ind_9        ind_10  \
# ind_109
# GREEN     5169   -507  171421.428572  128021.428572  43400.000000
# RED     -10122  -4448  126992.857144  169778.571429 -42785.714285
#
#                 ind_12         ind_13    ind_14    ind_15    ind_16  ...  \
# ind_109                                                              ...
# GREEN    171508.258069   25657.827773  36372.95  36667.88  36742.07  ...
# RED      133689.585179 -139732.019633  36221.80  35939.60  35864.44  ...
#
#           ind_412   ind_414  ind_416  ind_418      ind_424     ind_426  \
# ind_109
# GREEN    0.924815   64861.0 -35203.7  -111658  2201.553410  1777.18802
# RED      0.455597  111078.6 -17553.7   -62046   822.105226  1295.13864
#
#              ind_428    20_target     50_target     90_target
# ind_109
# GREEN    1616.716007 -1556.271553 -11070.110793 -12604.241816
# RED      1406.187082  1204.125197  -6853.400781  -7839.809419
#
# [2 rows x 133 columns]

# %%
int_columns=[]
for i in data.columns:
    if data[i].dtypes == np.int64:
        int_columns.append(i)

# %%
int_data = data[int_columns]

# %%
important_ = int_data.corr()[int_data.corr()>0.9 ].isnull().sum().index

# %%
quant_col =[]
for i in data.columns:
    if data[i].dtypes != np.object:
        quant_col.append(i)

# %%
column_list=[]
for i in quant_col:
    column_list.append(i)

# %%
len(column_list)
# Out:
# 133

# %%
data[column_list]
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0        19     17  100.000000  85.714286  14.285714  72.363515  60.808814
# 1        24     19  100.000000  78.571429  21.428571  74.275883  64.366798
# 2        30     24  100.000000  71.428571  28.571429  75.140402  65.915803
# 3        37     30  100.000000  64.285714  35.714286  76.677846  68.584234
# 4        41     37  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162     27     31   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163     22     27   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164     19     22   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165     19     19  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166     19     19   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
df  = data[column_list]
df.corr()
# Out:
#               ind_5     ind_6     ind_8     ind_9    ind_10    ind_12  \
# ind_5      1.000000  0.989945  0.543246 -0.533328  0.649225  0.822255
# ind_6      0.989945  1.000000  0.514222 -0.495572  0.608947  0.768551
# ind_8      0.543246  0.514222  1.000000 -0.374857  0.828650  0.583623
# ind_9     -0.533328 -0.495572 -0.374857  1.000000 -0.829576 -0.609288
# ind_10     0.649225  0.608947  0.828650 -0.829576  1.000000  0.719409
# ...             ...       ...       ...       ...       ...       ...
# ind_426    0.626439  0.567359  0.593799 -0.631961  0.739227  0.776076
# ind_428    0.817302  0.810371  0.445427 -0.450719  0.540428  0.807595
# 20_target  0.060969  0.062101 -0.004126 -0.031316  0.016423  0.042550
# 50_target  0.068989  0.069652  0.006984 -0.004053  0.006654  0.055045
# 90_target  0.060428  0.061560 -0.006650  0.012093 -0.011307  0.043786
#
#              ind_13    ind_14    ind_15    ind_16  ...   ind_412   ind_414  \
# ...

# %%
df.corr()[df.corr()>0.7].isnull().sum()<100
# Out:
# ind_5        False
# ind_6        False
# ind_8        False
# ind_9        False
# ind_10       False
#              ...
# ind_426      False
# ind_428      False
# 20_target    False
# 50_target    False
# 90_target    False
# Length: 133, dtype: bool

# %%
df.corr()[df.corr()[df.corr()>0.7].isnull().sum()<110]
# Out:
#             ind_5     ind_6     ind_8     ind_9    ind_10    ind_12    ind_13  \
# ind_5    1.000000  0.989945  0.543246 -0.533328  0.649225  0.822255  0.768234
# ind_12   0.822255  0.768551  0.583623 -0.609288  0.719409  1.000000  0.917026
# ind_13   0.768234  0.713870  0.482220 -0.568581  0.633753  0.917026  1.000000
# ind_33   0.690515  0.619709  0.580747 -0.624627  0.726938  0.900187  0.797652
# ind_34   0.761381  0.701955  0.559016 -0.598134  0.697852  0.915174  0.820723
# ind_35   0.805068  0.756306  0.540074 -0.577169  0.673785  0.911419  0.819268
# ind_41   0.742937  0.681285  0.589812 -0.609789  0.723439  0.925782  0.840507
# ind_102  0.932421  0.896699  0.535094 -0.541854  0.649463  0.933131  0.871274
# ind_118  0.962476  0.938138  0.537349 -0.549667  0.655538  0.895024  0.826481
# ind_139  0.778405  0.710757  0.654913 -0.676023  0.802642  0.928083  0.855972
# ind_142  0.915065  0.913761  0.522434 -0.528184  0.633584  0.851946  0.777536
# ...

# %%
columns_lt35 = df.corr()[df.corr()[df.corr()>0.7].isnull().sum()<35].index

# %%
data[columns_lt35].corr()
# Out:
#            ind_44    ind_45    ind_46    ind_47    ind_48    ind_49    ind_50  \
# ind_44   1.000000  0.935709  0.855908  0.730916  0.644274  0.588265  0.413642
# ind_45   0.935709  1.000000  0.961093  0.853383  0.767405  0.708730  0.516435
# ind_46   0.855908  0.961093  1.000000  0.932325  0.854701  0.796587  0.599305
# ind_47   0.730916  0.853383  0.932325  1.000000  0.960719  0.912158  0.726721
# ind_48   0.644274  0.767405  0.854701  0.960719  1.000000  0.976076  0.818542
# ind_49   0.588265  0.708730  0.796587  0.912158  0.976076  1.000000  0.883182
# ind_50   0.413642  0.516435  0.599305  0.726721  0.818542  0.883182  1.000000
# ind_58   0.723921  0.838782  0.862132  0.822832  0.773580  0.735735  0.569536
# ind_61   0.585422  0.755419  0.841624  0.889365  0.879888  0.860495  0.715804
# ind_67   0.443895  0.616072  0.730905  0.854180  0.905858  0.926789  0.871854
# ind_70   0.367448  0.524320  0.638830  0.782959  0.861927  0.906996  0.934126
# ...

# %%
obj_columns=[]
for i in data.columns:
    if data[i].dtypes == np.object:
        obj_columns.append(i)

# %%
obj_columns
# Out:
# ['ind_109', 'ind_420', 'ind_422']

# %%
data[obj_columns]
# Out:
#      ind_109 ind_420 ind_422
# 0      GREEN    -152    -353
# 1      GREEN    -158    -359
# 2      GREEN    -160    -362
# 3      GREEN    -166    -367
# 4      GREEN    -186    -388
# ...      ...     ...     ...
# 6162     RED     -11    -270
# 6163     RED     -12    -271
# 6164   GREEN     -21    -280
# 6165   GREEN     -33    -292
# 6166   GREEN     -28    -288
#
# [6167 rows x 3 columns]

# %%
data.iloc[:,-3:].corr()
# Out:
#            20_target  50_target  90_target
# 20_target   1.000000   0.384076   0.355950
# 50_target   0.384076   1.000000   0.940916
# 90_target   0.355950   0.940916   1.000000

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
for col in int_columns:
    
    X = data[[col]]

    X = sm.add_constant(X)  

    y= data["20_target"]
    
    
    
    
    
    lm = sm.OLS(y, X)
    model = lm.fit()
    if model.f_pvalue < 0.05:
        print(col)
        print(model.params)
        print("r2: " + "%.5f" %model.rsquared_adj)
        print("------------------")
# Out:
# ind_5
# const   -0.026354
# ind_5    0.038284
# dtype: float64
# r2: 0.00356
# ------------------
# ind_6
# const   -0.025770
# ind_6    0.038996
# dtype: float64
# r2: 0.00369
# ------------------
# ind_19
# const    -0.028935
# ind_19    0.105084
# dtype: float64
# r2: 0.00383
# ------------------
# ind_20
# const    -0.019543
# ind_20    0.051910
# dtype: float64
# r2: 0.00427
# ------------------
# ind_21
# const    -0.018846
# ind_21    0.086103
# dtype: float64
# r2: 0.00394
# ------------------
# ind_22
# const     0.314080
# ind_22    0.014292
# dtype: float64
# r2: 0.00055
# ------------------
# ind_23
# const    -0.494574
# ind_23    0.017537
# dtype: float64
# r2: 0.00069
# ------------------
# ind_47
# const    -0.048347
# ind_47   -0.023191
# dtype: float64
# r2: 0.00094
# ------------------
# ind_48
# const    -0.044601
# ind_48   -0.027155
# dtype: float64
# r2: 0.00192
# ------------------
# ind_49
# const    -0.037997
# ind_49   -0.028072
# dtype: float64
# ...

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
for col in int_columns:
    
    X = data[[col]]

    X = sm.add_constant(X)  

    y= data["50_target"]
    
    
    lm = sm.OLS(y, X)
    model = lm.fit()
    if model.f_pvalue < 0.05:
        print(col)
        print(model.params)
        print("r2: " + "%.5f" %model.rsquared_adj)
        print("------------------")
# Out:
# ind_5
# const   -2.825303
# ind_5    0.100922
# dtype: float64
# r2: 0.00460
# ------------------
# ind_6
# const   -2.824489
# ind_6    0.101894
# dtype: float64
# r2: 0.00469
# ------------------
# ind_19
# const    -2.844030
# ind_19    0.232534
# dtype: float64
# r2: 0.00344
# ------------------
# ind_20
# const    -2.814454
# ind_20    0.127023
# dtype: float64
# r2: 0.00473
# ------------------
# ind_21
# const    -2.806190
# ind_21    0.225452
# dtype: float64
# r2: 0.00501
# ------------------
# ind_23
# const    -5.934035
# ind_23    0.121373
# dtype: float64
# r2: 0.00735
# ------------------
# ind_47
# const    -2.885949
# ind_47   -0.054066
# dtype: float64
# r2: 0.00094
# ------------------
# ind_48
# const    -2.876029
# ind_48   -0.065884
# dtype: float64
# r2: 0.00210
# ------------------
# ind_49
# const    -2.858986
# ind_49   -0.069608
# dtype: float64
# r2: 0.00317
# ------------------
# ind_50
# const    -2.824365
# ind_50   -0.040465
# dtype: float64
# ...

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
for col in int_columns:
    
    X = data[[col]]

    X = sm.add_constant(X)  

    y= data["90_target"]
    
    
    lm = sm.OLS(y, X)
    model = lm.fit()
    if model.f_pvalue < 0.05:
        print(col)
        print(model.params)
        print("r2: " + "%.5f" %model.rsquared_adj)
        print("------------------")
# Out:
# ind_5
# const   -3.239387
# ind_5    0.094236
# dtype: float64
# r2: 0.00349
# ------------------
# ind_6
# const   -3.237938
# ind_6    0.096002
# dtype: float64
# r2: 0.00363
# ------------------
# ind_19
# const    -3.258354
# ind_19    0.211604
# dtype: float64
# r2: 0.00247
# ------------------
# ind_20
# const    -3.229745
# ind_20    0.117933
# dtype: float64
# r2: 0.00355
# ------------------
# ind_21
# const    -3.220888
# ind_21    0.211984
# dtype: float64
# r2: 0.00387
# ------------------
# ind_23
# const    -6.426742
# ind_23    0.124740
# dtype: float64
# r2: 0.00682
# ------------------
# ind_48
# const    -3.288978
# ind_48   -0.056684
# dtype: float64
# r2: 0.00131
# ------------------
# ind_49
# const    -3.273908
# ind_49   -0.060486
# dtype: float64
# r2: 0.00205
# ------------------
# ind_50
# const    -3.247288
# ind_50   -0.033453
# dtype: float64
# r2: 0.00147
# ------------------
# ind_51
# const    -3.247352
# ind_51   -0.019439
# dtype: float64
# ...

# %%
_columns=[]
for i in data.columns:
    if data[i].dtypes != np.object:
        _columns.append(i)
_columns = _columns[:-3]
_columns
# Out:
# ['ind_5',
#  'ind_6',
#  'ind_8',
#  'ind_9',
#  'ind_10',
#  'ind_12',
#  'ind_13',
#  'ind_14',
#  'ind_15',
#  'ind_16',
#  'ind_17',
#  'ind_18',
#  'ind_19',
#  'ind_20',
#  'ind_21',
#  'ind_22',
#  'ind_23',
#  'ind_25',
#  'ind_26',
#  'ind_27',
#  'ind_28',
#  'ind_29',
#  'ind_30',
#  'ind_31',
#  'ind_32',
#  'ind_33',
#  'ind_34',
#  'ind_35',
#  'ind_36',
#  'ind_37',
#  'ind_39',
#  'ind_40',
#  'ind_41',
#  'ind_42',
#  'ind_43',
#  'ind_44',
#  'ind_45',
#  'ind_46',
#  'ind_47',
#  'ind_48',
#  'ind_49',
#  'ind_50',
#  'ind_51',
#  'ind_52',
#  'ind_53',
#  'ind_56',
#  'ind_58',
#  'ind_61',
#  'ind_62',
#  'ind_65',
#  'ind_67',
#  'ind_70',
#  'ind_71',
#  'ind_74',
#  'ind_77',
#  'ind_82',
#  'ind_83',
#  'ind_88',
#  'ind_92',
#  'ind_102',
#  'ind_116',
#  'ind_118',
#  'ind_122',
#  'ind_124',
#  'ind_128',
#  'ind_130',
#  'ind_132',
#  'ind_134',
#  'ind_136',
#  'ind_139',
#  'ind_142',
#  'ind_145',
#  'ind_147',
#  'ind_150',
#  'ind_153',
# ...

# %%
import random
def random_select():
    j = len(_columns)-1
    liste = []
    for i in range(5):
        c=random.randint(0, j)
        liste.append(_columns[c])
    return liste

# %%
for i in range(5000):
    l = random_select()
    X = data[l]

    X = sm.add_constant(X)  

    y= data["90_target"]
    
    
    lm = sm.OLS(y, X)
    model = lm.fit()
    if model.rsquared_adj > 0.05:
        print(l)
        print(model.params)
        print("r2: " + "%.5f" %model.rsquared_adj)
        print("------------------")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-322-feb41d91172f> in <module>
#       3     X = data[l]
#       4
# ----> 5     X = sm.add_constant(X)
#       6
#       7     y= data["90_target"]
#
# c:\python38\lib\site-packages\statsmodels\tools\tools.py in add_constant(data, prepend, has_constant)
#     314             warnings.warn(recarray_warning, FutureWarning)
#     315         from statsmodels.tsa.tsatools import add_trend
# --> 316         return add_trend(data, trend='c', prepend=prepend, has_constant=has_constant)
#     317
#     318     # Special case for NumPy
#
# c:\python38\lib\site-packages\statsmodels\tsa\tsatools.py in add_trend(x, trend, prepend, has_constant)
#     108                 except:
#     109                     return False
# --> 110             col_const = x.apply(safe_is_const, 0)
#     111         else:
# ...

# %%
data
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0        19     17  100.000000  85.714286  14.285714  72.363515  60.808814
# 1        24     19  100.000000  78.571429  21.428571  74.275883  64.366798
# 2        30     24  100.000000  71.428571  28.571429  75.140402  65.915803
# 3        37     30  100.000000  64.285714  35.714286  76.677846  68.584234
# 4        41     37  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162     27     31   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163     22     27   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164     19     22   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165     19     19  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166     19     19   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
target_data = data.corr().iloc[:,-3:]

# %%
target_data[target_data>0.3]
# Out:
#            20_target  50_target  90_target
# ind_5            NaN        NaN        NaN
# ind_6            NaN        NaN        NaN
# ind_8            NaN        NaN        NaN
# ind_9            NaN        NaN        NaN
# ind_10           NaN        NaN        NaN
# ...              ...        ...        ...
# ind_426          NaN        NaN        NaN
# ind_428          NaN        NaN        NaN
# 20_target   1.000000   0.384076   0.355950
# 50_target   0.384076   1.000000   0.940916
# 90_target   0.355950   0.940916   1.000000
#
# [133 rows x 3 columns]

# %%
target_data[target_data>0.3].isnull().sum()
# Out:
# 20_target    130
# 50_target    130
# 90_target    130
# dtype: int64

# %%
a=data[["ind_420", "ind_422"]]

# %%
a.replace('?',np.nan)
# Out:
#       ind_420  ind_422
# 0      -152.0   -353.0
# 1      -158.0   -359.0
# 2      -160.0   -362.0
# 3      -166.0   -367.0
# 4      -186.0   -388.0
# ...       ...      ...
# 6162    -11.0   -270.0
# 6163    -12.0   -271.0
# 6164    -21.0   -280.0
# 6165    -33.0   -292.0
# 6166    -28.0   -288.0
#
# [6167 rows x 2 columns]

# %%
data["ind_420"]=pd.to_numeric(data["ind_420"], errors = 'coerce')

# %%
data["ind_422"]=pd.to_numeric(data["ind_422"], errors = 'coerce')

# %%
data.corr()[data.corr()>0.5].isnull().sum()<100
# Out:
# ind_5         True
# ind_6        False
# ind_8        False
# ind_9        False
# ind_10       False
#              ...
# ind_426       True
# ind_428      False
# 20_target    False
# 50_target    False
# 90_target    False
# Length: 135, dtype: bool

# %%
data.corr()[data.corr()[data.corr()>0.5].isnull().sum()<105]
# Out:
#             ind_5     ind_6     ind_8     ind_9    ind_10    ind_12    ind_13  \
# ind_5    1.000000  0.989945  0.543246 -0.533328  0.649225  0.822255  0.768234
# ind_6    0.989945  1.000000  0.514222 -0.495572  0.608947  0.768551  0.713870
# ind_10   0.649225  0.608947  0.828650 -0.829576  1.000000  0.719409  0.633753
# ind_12   0.822255  0.768551  0.583623 -0.609288  0.719409  1.000000  0.917026
# ind_13   0.768234  0.713870  0.482220 -0.568581  0.633753  0.917026  1.000000
# ind_19   0.959186  0.970076  0.529149 -0.513249  0.628610  0.722079  0.672458
# ind_20   0.933323  0.967333  0.457287 -0.438004  0.539894  0.702504  0.639412
# ind_22   0.645180  0.584400  0.480519 -0.434101  0.551531  0.703962  0.777598
# ind_23   0.550404  0.487505  0.401198 -0.506541  0.547493  0.703068  0.544912
# ind_30   0.329814  0.240259  0.434497 -0.467668  0.544078  0.700750  0.623227
# ind_31   0.466513  0.379384  0.572986 -0.604192  0.709925  0.792455  0.699256
# ...

# %%
pd.get_dummies(data["ind_109"])
# Out:
#       GREEN  RED
# 0         1    0
# 1         1    0
# 2         1    0
# 3         1    0
# 4         1    0
# ...     ...  ...
# 6162      0    1
# 6163      0    1
# 6164      1    0
# 6165      1    0
# 6166      1    0
#
# [6167 rows x 2 columns]

# %%
dummy = data.join(pd.get_dummies(data["ind_109"]))
dummy
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0        19     17  100.000000  85.714286  14.285714  72.363515  60.808814
# 1        24     19  100.000000  78.571429  21.428571  74.275883  64.366798
# 2        30     24  100.000000  71.428571  28.571429  75.140402  65.915803
# 3        37     30  100.000000  64.285714  35.714286  76.677846  68.584234
# 4        41     37  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162     27     31   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163     22     27   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164     19     22   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165     19     19  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166     19     19   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
dummy.corr()[dummy.corr()["90_target"]>0.3]
# Out:
#               ind_5     ind_6     ind_8     ind_9    ind_10    ind_12  \
# 20_target  0.060969  0.062101 -0.004126 -0.031316  0.016423  0.042550
# 50_target  0.068989  0.069652  0.006984 -0.004053  0.006654  0.055045
# 90_target  0.060428  0.061560 -0.006650  0.012093 -0.011307  0.043786
#
#              ind_13    ind_14    ind_15    ind_16  ...   ind_416   ind_418  \
# 20_target  0.041289  0.015320  0.012012  0.026881  ... -0.009829 -0.045656
# 50_target  0.048302  0.072728  0.084561  0.101774  ...  0.047728 -0.101488
# 90_target  0.043491  0.077710  0.088271  0.108077  ...  0.049615 -0.096903
#
#             ind_424   ind_426   ind_428  20_target  50_target  90_target  \
# 20_target -0.008799  0.019599  0.047041   1.000000   0.384076   0.355950
# 50_target -0.003372  0.009063  0.052418   0.384076   1.000000   0.940916
# 90_target -0.007689 -0.002519  0.043563   0.355950   0.940916   1.000000
#
#               GREEN       RED
# 20_target -0.030119  0.030119
# ...

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

X = dummy[["GREEN", "ind_416"]]

X = sm.add_constant(X)  

y= dummy["90_target"]


lm = sm.OLS(y, X)
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     8.002
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           0.000338
# Time:                        12:19:38   Log-Likelihood:                -30984.
# No. Observations:                6167   AIC:                         6.197e+04
# Df Residuals:                    6164   BIC:                         6.199e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.9522      0.689     -2.831      0.005      -3.304      -0.601
# ...

# %%
tar90 =[]
for col in _columns:
    if data[["90_target", col]].corr().iloc[0,1] > 0.1 or data[["90_target", col]].corr().iloc[0,1] < -0.1 :
        print(col)
        tar90.append(col)
# Out:
# ind_16
# ind_17
# ind_18
# ind_324
# ind_332
# ind_412

# %%
tar90.remove("ind_16")

X = data[tar90]

X = sm.add_constant(X)  

y= data["90_target"]


lm = sm.OLS(y, X)
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     62.63
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           6.50e-64
# Time:                        14:01:07   Log-Likelihood:                -30839.
# No. Observations:                6167   AIC:                         6.169e+04
# Df Residuals:                    6161   BIC:                         6.173e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -25.8741      2.068    -12.509      0.000     -29.929     -21.819
# ...

# %%
plt.plot(model.resid)

# %%
advres = pd.concat([data , pd.Series(model.resid, name = 'resid'), pd.Series(model.predict(), name = "predict")], axis = 1)

# %%
import seaborn as sns
sns.distplot(np.array(advres.resid), hist=False)

# %%
from itertools import combinations
import matplotlib.pyplot as plt

fig, axes = plt.subplots(len(_columns)//3, 3, figsize=(36, 120))

i = 0
for triaxis in axes:
    for axis in triaxis:
        data.hist(column = _columns[i], ax=axis)
        i = i+1

# %%
data
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0        19     17  100.000000  85.714286  14.285714  72.363515  60.808814
# 1        24     19  100.000000  78.571429  21.428571  74.275883  64.366798
# 2        30     24  100.000000  71.428571  28.571429  75.140402  65.915803
# 3        37     30  100.000000  64.285714  35.714286  76.677846  68.584234
# 4        41     37  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162     27     31   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163     22     27   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164     19     22   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165     19     19  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166     19     19   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
data.hist("20_target");
data.hist("50_target");
data.hist("90_target");

# %%
data.replace('?',np.nan, inplace=True)

# %%
data["ind_422"].fillna(data["ind_422"].median(), inplace=True)
data["ind_420"].fillna(data["ind_420"].median(), inplace=True)

# %%
sol = data[(data["90_target"] < 40) & (data["90_target"] > 10 )]
orta = data[(data["90_target"] < 10) & (data["90_target"] > -10 )]
sag = data[(data["90_target"] < -10) & (data["90_target"] > -40 )]

# %%
print(len(sol)+len(sag)+len(orta))
# Out:
# 6167

# %%
X = sol.drop(["20_target","50_target","90_target","ind_109"], axis = 1)
X = sm.add_constant(X)
y = sol["90_target"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
ols_model = sm.OLS(y_train, X_train.astype(float))
model = ols_model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     2250.
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):               0.00
# Time:                        17:21:54   Log-Likelihood:                 2649.7
# No. Observations:                2218   AIC:                            -5033.
# Df Residuals:                    2085   BIC:                            -4275.
# Df Model:                         132
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         37.6303      0.159    236.439      0.000      37.318      37.942
# ...

# %%
from sklearn.linear_model import LinearRegression

X = sol.drop(["20_target","50_target","90_target","ind_109"], axis = 1)
y = sol["90_target"]
reg = LinearRegression()
model_reg = reg.fit(X, y)
model_reg.predict(X)
# Out:
# array([36.74671827, 36.78402958, 37.10195725, ..., 35.81295945,
#        35.81595294, 35.86410711])

# %%
k_t = pd.DataFrame({"gercek_y": y[:10], "tahmin_y": reg.predict(X)[:10]})
k_t
# Out:
#      gercek_y   tahmin_y
# 0   36.997753  36.746718
# 1   37.016198  36.784030
# 49  37.002364  37.101957
# 51  37.002671  37.144805
# 52  37.003901  37.137102
# 53  36.981767  37.133898
# 54  36.940881  36.868124
# 55  36.935348  36.864667
# 56  36.933196  36.890344
# 57  36.950719  36.911874

# %%
k_t["hata"] = k_t["gercek_y"] - k_t["tahmin_y"]
k_t
# Out:
#      gercek_y   tahmin_y      hata
# 0   36.997753  36.746718  0.251034
# 1   37.016198  36.784030  0.232168
# 49  37.002364  37.101957 -0.099593
# 51  37.002671  37.144805 -0.142134
# 52  37.003901  37.137102 -0.133201
# 53  36.981767  37.133898 -0.152130
# 54  36.940881  36.868124  0.072757
# 55  36.935348  36.864667  0.070681
# 56  36.933196  36.890344  0.042852
# 57  36.950719  36.911874  0.038844

# %%
k_t["hata_kare"] = k_t["hata"]**2
k_t
# Out:
#      gercek_y   tahmin_y      hata  hata_kare
# 0   36.997753  36.746718  0.251034   0.063018
# 1   37.016198  36.784030  0.232168   0.053902
# 49  37.002364  37.101957 -0.099593   0.009919
# 51  37.002671  37.144805 -0.142134   0.020202
# 52  37.003901  37.137102 -0.133201   0.017742
# 53  36.981767  37.133898 -0.152130   0.023144
# 54  36.940881  36.868124  0.072757   0.005294
# 55  36.935348  36.864667  0.070681   0.004996
# 56  36.933196  36.890344  0.042852   0.001836
# 57  36.950719  36.911874  0.038844   0.001509

# %%
np.sum(k_t["hata_kare"])
# Out:
# 0.20156177086730298

# %%
np.mean(k_t["hata_kare"]) # mean squared error
# Out:
# 0.020156177086730297

# %%
plt.plot(model.resid)

# %%
influence = model.get_influence()

resid_student = influence.resid_studentized_external

(cooks, p) = influence.cooks_distance
(dffits, p ) = influence.dffits
leverage = influence.hat_matrix_diag
print("Leverage vs Studentized Residuals")
sns.regplot(leverage, model.resid_pearson, fit_reg=False)
# Out:
# Leverage vs Studentized Residuals

# %%
X = sag.drop(["20_target","50_target","90_target","ind_109"], axis = 1)
X = sm.add_constant(X)
y = sag["90_target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

ols_model = sm.OLS(y_train, X_train.astype(float))
model = ols_model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     2410.
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):               0.00
# Time:                        18:48:33   Log-Likelihood:                 3034.1
# No. Observations:                2654   AIC:                            -5802.
# Df Residuals:                    2521   BIC:                            -5020.
# Df Model:                         132
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -37.7827      0.140   -270.520      0.000     -38.057     -37.509
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif
# Out:
# c:\python38\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#       VIF Factor features
# 0    8208.816775    const
# 1    1949.760552    ind_5
# 2    1234.834204    ind_6
# 3            inf    ind_8
# 4            inf    ind_9
# ..           ...      ...
# 128     3.939258  ind_420
# 129     4.676931  ind_422
# 130     3.683663  ind_424
# 131     8.319896  ind_426
# 132    11.789675  ind_428
#
# [133 rows x 2 columns]

# %%
for index, row in vif.iterrows():
    print(row[0], row[1])
# Out:
# 8208.816774674171 const
# 1949.7605520284717 ind_5
# 1234.8342037028253 ind_6
# inf ind_8
# inf ind_9
# inf ind_10
# 3231.947749919114 ind_12
# 16.046353328202283 ind_13
# 6.590732250491392 ind_14
# 10.630203152416613 ind_15
# 17.519182586581184 ind_16
# 15.872499161131786 ind_17
# 3.0408176084234255 ind_18
# 648.8668745664622 ind_19
# 1806.247620005151 ind_20
# 836.6664780059748 ind_21
# 468.8153784620087 ind_22
# 287.8312500959037 ind_23
# 10072886.468142997 ind_25
# 7942786.47847455 ind_26
# 6527630.536629659 ind_27
# 2.880772982352758 ind_28
# 14.408870210211614 ind_29
# 22.872968483054144 ind_30
# 50.03416887120029 ind_31
# 48.71621455451668 ind_32
# 49.496277760568034 ind_33
# 59.41132632204974 ind_34
# 35.52134705912887 ind_35
# 21.6324178811713 ind_36
# 24.16526698978349 ind_37
# 35.460077749003645 ind_39
# 4.578789073932621 ind_40
# 12.138297601555145 ind_41
# 24.99102006390411 ind_42
# 25.776222606821694 ind_43
# 48.4438703204826 ind_44
# 67.7805378456846 ind_45
# ...

# %%
vif_list=[]

for index, row in vif.iterrows():
    if row[0]>10:
        vif_list.append(row[1])
vif_list
# Out:
# ['const',
#  'ind_5',
#  'ind_6',
#  'ind_8',
#  'ind_9',
#  'ind_10',
#  'ind_12',
#  'ind_13',
#  'ind_15',
#  'ind_16',
#  'ind_17',
#  'ind_19',
#  'ind_20',
#  'ind_21',
#  'ind_22',
#  'ind_23',
#  'ind_25',
#  'ind_26',
#  'ind_27',
#  'ind_29',
#  'ind_30',
#  'ind_31',
#  'ind_32',
#  'ind_33',
#  'ind_34',
#  'ind_35',
#  'ind_36',
#  'ind_37',
#  'ind_39',
#  'ind_41',
#  'ind_42',
#  'ind_43',
#  'ind_44',
#  'ind_45',
#  'ind_46',
#  'ind_47',
#  'ind_48',
#  'ind_49',
#  'ind_50',
#  'ind_51',
#  'ind_52',
#  'ind_56',
#  'ind_58',
#  'ind_61',
#  'ind_67',
#  'ind_70',
#  'ind_74',
#  'ind_82',
#  'ind_92',
#  'ind_102',
#  'ind_116',
#  'ind_118',
#  'ind_122',
#  'ind_124',
#  'ind_128',
#  'ind_130',
#  'ind_132',
#  'ind_136',
#  'ind_139',
#  'ind_142',
#  'ind_145',
#  'ind_147',
#  'ind_150',
#  'ind_153',
#  'ind_156',
#  'ind_164',
#  'ind_168',
#  'ind_179',
#  'ind_181',
#  'ind_188',
#  'ind_194',
#  'ind_212',
#  'ind_225',
#  'ind_234',
#  'ind_241',
# ...

# %%
len(vif_list)
# Out:
# 36

# %%
for col in vif_list:
    X = X.drop(col, axis = 1)

# %%
X
# Out:
#       ind_14   ind_18     ind_28  ind_40  ind_53  ind_62  ind_65  ind_71  \
# 2       8.75   9.3125  66.666667       3      17      11      10       8
# 3       7.80   9.4150  66.666667       3      14      11      10       8
# 4      14.90   9.8925  66.666667       2      28      12      11       9
# 5      18.75  10.2175  66.666667       2      26      14      12       9
# 6      15.45  10.4650  66.666667       2      21      15      13      10
# ...      ...      ...        ...     ...     ...     ...     ...     ...
# 6162    9.70  16.2175 -66.666667       4     -10      14      15      15
# 6163    7.65  16.1175 -66.666667       4     -10      14      14      15
# 6164    8.95  16.3125  66.666667       4      13      13      14      15
# 6165   13.55  16.4200  66.666667       4      19      13      14      15
# 6166   11.45  16.4500 -66.666667       4      12      13      14      14
#
#       ind_77  ind_83  ...   ind_334   ind_340  ind_344    ind_397   ind_412  \
# ...

# %%
X = X
X = sm.add_constant(X)
y = sag["90_target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

ols_model = sm.OLS(y_train, X_train.astype(float))
model = ols_model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared:                       0.586
# Model:                            OLS   Adj. R-squared:                  0.580
# Method:                 Least Squares   F-statistic:                     102.9
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):               0.00
# Time:                        18:49:39   Log-Likelihood:                -2226.2
# No. Observations:                2654   AIC:                             4526.
# Df Residuals:                    2617   BIC:                             4744.
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -36.8278      0.161   -228.094      0.000     -37.144     -36.511
# ...

# %%
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif
# Out:
#     VIF Factor features
# 0   212.022073    const
# 1     1.370918   ind_14
# 2     1.864071   ind_18
# 3     1.944320   ind_28
# 4     1.728750   ind_40
# 5     3.597701   ind_53
# 6     6.696989   ind_62
# 7     7.961530   ind_65
# 8     5.219259   ind_71
# 9     4.272568   ind_77
# 10    2.752254   ind_83
# 11    1.294131   ind_88
# 12    2.286887  ind_134
# 13    1.243234  ind_172
# 14    1.267742  ind_176
# 15    1.231617  ind_217
# 16    1.362333  ind_228
# 17    1.409172  ind_237
# 18    1.236715  ind_239
# 19    1.391241  ind_309
# 20    1.456825  ind_310
# 21    1.780259  ind_315
# 22    2.205411  ind_321
# 23    1.998285  ind_324
# 24    2.153150  ind_327
# 25    3.140472  ind_330
# 26    3.053886  ind_332
# 27    1.506669  ind_334
# 28    1.460007  ind_340
# 29    1.377200  ind_344
# 30    1.554444  ind_397
# 31    1.531103  ind_412
# 32    1.391963  ind_416
# 33    2.707216  ind_420
# 34    2.835813  ind_422
# 35    2.223928  ind_424
# 36    2.568046  ind_426

# %%
colo=["ind_71","ind_316" ,"ind_18","ind_124","ind_153","ind_32" ,"ind_20",
 "ind_406" ,"ind_37","ind_41","ind_47","ind_33" ,"ind_181" ,"ind_58"]

# %%
X = sag[colo]
# X = sm.add_constant(X)
y = sag["90_target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

ols_model = sm.OLS(y_train, X_train.astype(float))
model = ols_model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          1.167e+05
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):                        0.00
# Time:                        21:36:30   Log-Likelihood:                         -4834.1
# No. Observations:                2654   AIC:                                      9696.
# Df Residuals:                    2640   BIC:                                      9779.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
colo2=["ind_71","ind_316" ,"ind_18","ind_124","ind_153","ind_32" ,"ind_20",
 "ind_406" ,"ind_37","ind_41" ,"ind_181" ,"ind_58"]

# %%
X = sag[colo2]
X = sm.add_constant(X)
y = sag["90_target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

ols_model = sm.OLS(y_train, X_train.astype(float))
model = ols_model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared:                       0.181
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     48.78
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):          1.04e-105
# Time:                        21:37:59   Log-Likelihood:                -3130.6
# No. Observations:                2654   AIC:                             6287.
# Df Residuals:                    2641   BIC:                             6364.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -36.5269      0.440    -83.074      0.000     -37.389     -35.665
# ...
